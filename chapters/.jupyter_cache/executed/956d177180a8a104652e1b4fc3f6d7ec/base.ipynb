# %%
# imports
import os
import sys
import types
import json

# figure size/format
fig_width = 7
fig_height = 5
fig_format = 'retina'
fig_dpi = 96

# matplotlib defaults / format
try:
  import matplotlib.pyplot as plt
  plt.rcParams['figure.figsize'] = (fig_width, fig_height)
  plt.rcParams['figure.dpi'] = fig_dpi
  plt.rcParams['savefig.dpi'] = fig_dpi
  from IPython.display import set_matplotlib_formats
  set_matplotlib_formats(fig_format)
except Exception:
  pass

# plotly use connected mode
try:
  import plotly.io as pio
  pio.renderers.default = "notebook_connected"
except Exception:
  pass

# enable pandas latex repr when targeting pdfs
try:
  import pandas as pd
  if fig_format == 'pdf':
    pd.set_option('display.latex.repr', True)
except Exception:
  pass



# output kernel dependencies
kernel_deps = dict()
for module in list(sys.modules.values()):
  # Some modules play games with sys.modules (e.g. email/__init__.py
  # in the standard library), and occasionally this can cause strange
  # failures in getattr.  Just ignore anything that's not an ordinary
  # module.
  if not isinstance(module, types.ModuleType):
    continue
  path = getattr(module, "__file__", None)
  if not path:
    continue
  if path.endswith(".pyc") or path.endswith(".pyo"):
    path = path[:-1]
  if not os.path.exists(path):
    continue
  kernel_deps[path] = os.stat(path).st_mtime
print(json.dumps(kernel_deps))

# set run_path if requested
if r'/Users/legoses/Library/CloudStorage/GoogleDrive-nelsonla@byui.edu/My Drive/PH135/textbook/chapters':
  os.chdir(r'/Users/legoses/Library/CloudStorage/GoogleDrive-nelsonla@byui.edu/My Drive/PH135/textbook/chapters')

# reset state
# %reset

def ojs_define(**kwargs):
  import json
  try:
    # IPython 7.14 preferred import
    from IPython.display import display, HTML
  except:
    from IPython.core.display import display, HTML

  # do some minor magic for convenience when handling pandas
  # dataframes
  def convert(v):
    try:
      import pandas as pd
    except ModuleNotFoundError: # don't do the magic when pandas is not available
      return v
    if type(v) == pd.Series:
      v = pd.DataFrame(v)
    if type(v) == pd.DataFrame:
      j = json.loads(v.T.to_json(orient='split'))
      return dict((k,v) for (k,v) in zip(j["index"], j["data"]))
    else:
      return v
  
  v = dict(contents=list(dict(name=key, value=convert(value)) for (key, value) in kwargs.items()))
  display(HTML('<script type="ojs-define">' + json.dumps(v) + '</script>'), metadata=dict(ojs_define = True))
globals()["ojs_define"] = ojs_define
# Out:
# {"/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/_bootstrap.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/_bootstrap_external.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipimport.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/codecs.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/encodings/aliases.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/encodings/__init__.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/encodings/utf_8.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/abc.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/io.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/stat.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/_collections_abc.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/genericpath.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/posixpath.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/os.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/_sitebuiltins.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/warnings.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/machinery.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/_abc.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/types.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/util.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/runpy.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/operator.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/keyword.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/reprlib.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/collections/__init__.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/functools.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/enum.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/re/_constants.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/re/_parser.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/re/_casefix.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/re/_compiler.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/copyreg.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/re/__init__.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/fnmatch.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ntpath.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/__init__.py": 1707257427.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/lib-dynload/math.cpython-312-darwin.so": 1707257703.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ipaddress.py": 1707257426.0, "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ ...
# /var/folders/l7/qksjftz12pz0s32y0l3jd4k4cyyb65/T/ipykernel_12845/3009046183.py:20: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats(fig_format)

# %%
thesum = 0
for i in [3,2,1,9.9]: 
    thesum += i

# %%
thesum = 0

thesum = thesum + 3
thesum = thesum + 2
thesum = thesum + 1
thesum = thesum + 9.9

# %%
for i in ['Physics', 'is','so','fun']: # Iterate over a list of strings
    print(i)
# Out:
# Physics
# is
# so
# fun

# %%
for i in range(5,50,3):  #Generates a list from 5 -> 50 with a step size of 3
    print(i)
# Out:
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29
# 32
# 35
# 38
# 41
# 44
# 47

# %%
theSum = 0
for n in range(1,1000):
    theSum = theSum + 1/n**2
print(theSum)
# Out:
# 1.6439335666815615

# %%
theProduct = 1
for n in range(1,21):
    theProduct = theProduct * n #Multiply theProduct by n
print(theProduct)
# Out:
# 2432902008176640000

# %%
from math import factorial
factorial(20)
# Out:
# 2432902008176640000

# %%
theSum = 0
for n in range(1,1000):
    if n % 5 == 0 and n % 3 == 0:
        theSum = theSum + 1/n**2
print(theSum)
# Out:
# 0.007243985583159138

# %%
AN = [1,2,3,4,5,6]
mass = [1,4,7,9,11,12]

zipped = zip(AN,mass)

for pair in zipped:
    print(pair[1] - pair[0])
# Out:
# 0
# 2
# 4
# 5
# 6
# 6

# %%
AN = [1,2,3,4,5,6]
mass = [1,4,7,9,11,12]

enum = enumerate(mass)

for idx,val in enum:
    print(val - AN[idx])
# Out:
# 0
# 2
# 4
# 5
# 6
# 6

# %%
myList = []

for i in range(10):
    myList.append(i**2)

print(myList)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
myList = [i**2 for i in range(10)]
print(myList)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
myList = [i**2 for i in range(10) if i %2 == 0]  # Include only the evens.
print(myList)
# Out:
# [0, 4, 16, 36, 64]

# %%
term = 1  # Load the first term in the sum
s = term  # Initialize the sum
n = 1     # Set a counter
while term > 1e-2:  # Loop while term is bigger than 1e-2
    n = n +  1        #Add 1 to n so that it will count: 2,3,4,5
    term = 1./n**2    # Calculate the next term to add
    s = s +  term     # Add 1/n^2 to the running total

# %%
#| eval: false
x = 0

while x != 10:
    x = x + 3
print("Done")

# %%
term = 1  # Load the first term in the sum
s = term  # Initialize the sum
n = 1     # Set a counter
while term > 1e-10:  # Loop while term is bigger than 1e-10
    n +=  1        #Add 1 to n so that it will count: 2,3,4,5
    term = 1./n**2    # Calculate the next term to add
    s += term     # Add 1/n^2 to the running total
    if n > 1000:
        print('This is taking too long. I''m outta here...')
        break
# Out:
# This is taking too long. Im outta here...

# %%
term = 1  # Load the first term in the sum
s = term  # Initialize the sum
n = 1     # Set a counter
while term > 1e-10:  # Loop while term is bigger than 1e-10
    n +=  1        #Add 1 to n so that it will count: 2,3,4,5
    if n % 3 != 0:
        continue
    term = 1./n**2    # Calculate the next term to add
    s += term     # Add 1/n^2 to the running total

# %%
# Python code here.

# %%
#Python code here

# %%
# Python code here

# %%
#Code here.

# %%
#| eval: true
from math import exp,sqrt
m = 20
g = 9.8
c = 0.75
v0=0

# %%
planetData = {"Mercury": [0.33e24,4.879e6],"Venus":[4.87e24,1.2104e7],"Earth":[5.97e24,1.2756e7],"Mars":[0.642e24,6.792e6],"Jupiter":[1.898e27,1.42984e8],"Saturn":[5.68e26,1.20536e8],"Uranus":[8.68e25,5.1118e7],"Neptune":[1.02e26,4.9528e7],"Pluto":[0.013e24,2.376e7]}

# %%
xold = 2 # starting guess
